# %% [markdown]
# ### **Nama : Anisa Fitriyani**
# ### **NIM : 122450019**
# ### **Kelas : RA**
# ### **Mata Kuliah : Visualisasi Data & Informasi**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data from the uploaded CSV file
file_path = '/content/Penyebab Kematian di Indonesia yang Dilaporkan - Clean.csv'
data = pd.read_csv(file_path)

# Data preparation: group by 'Cause' and 'Year' to get total deaths per cause each year
cause_trend = data.groupby(['Cause', 'Year'])['Total Deaths'].sum().reset_index()

# We will select some major causes of death for visualization purposes
major_causes = cause_trend.groupby('Cause')['Total Deaths'].sum().nlargest(5).index
filtered_data = cause_trend[cause_trend['Cause'].isin(major_causes)]

# Set the plot size
plt.figure(figsize=(10, 6))

# Plot the trend of deaths by major causes
sns.lineplot(data=filtered_data, x='Year', y='Total Deaths', hue='Cause', marker='o')

# Adding titles and labels
plt.title('Kematian di Indonesia Berdasarkan Beberapa Penyebab', fontsize=14)
plt.xlabel('Tahun', fontsize=12)
plt.ylabel('Jumlah Kematian', fontsize=12)
plt.legend(title='Penyebab', bbox_to_anchor=(1.05, 1), loc='upper left')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Data yang digunakan** :
# Dataset berisi penyebab kematian di Indonesia, termasuk informasi mengenai penyebab (seperti AIDS, Abrasi Air Laut), tipe penyebab (Bencana Alam, Bencana Non Alam dan Penyakit), tahun, jumlah kematian, serta sumber data.
#
# **Tujuan visualisasi** : Memvisualisasikan tren penyebab kematian terbesar dari waktu ke waktu untuk memberikan wawasan terkait perbedaan antara penyebab yang terkait bencana alam dan non-alam.
#
# **User**:
# Pembuat kebijakan kesehatan, peneliti bencana, dan masyarakat umum yang ingin memahami ancaman kesehatan publik dan alam yang berdampak signifikan di Indonesia.
#
# **Fungsi**:
# Membantu memprioritaskan sumber daya untuk mitigasi bencana atau penyakit berdasarkan frekuensi kematian dari penyebab tertentu selama periode waktu tertentu.
#
# **Tone**:
# Informasional dan analitis, menekankan data yang mendesak dan serius.
